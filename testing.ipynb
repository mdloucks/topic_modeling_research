# %% [markdown]
# Just a notebook for quick simple tests

# %%
import pandas as pd
from glob import glob
import pickle
import networkx as nx
import matplotlib.pyplot as plt

filenames = glob("data/BTC/*.csv")
nrows = 10000

for i, filename in enumerate(filenames):
    df = pd.read_csv(filename, nrows=nrows)
df = pickle.load(open("preprocessed_bitcoin_df.pkl", 'rb'))

# %%
data = None

with open("./preprocessed_bitcoin.pkl", 'rb') as f:
    data = pickle.load(f)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__func__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
# visualize the graph, showing the successors and predacessors
nx.draw_shell(data["user_network"], with_labels=True)

for user in data["user_network"].nodes:
    print(user)

    successors = data["user_network"].successors(user)

    for succ in successors:
        print(f"    -{succ}")
# Out:
# Tomas
#     -TraderSeneca
# TraderSeneca
# Joseph Krampe
#     -Bitcoin
# Bitcoin
# RoboCrypto
#     -RegalChicken
# RegalChicken
# g3nology
#     -g3nology
# dstadulis
#     -dstadulis
# Jessi Palmer
#     -Bitstamp
# Bitstamp
# I Pretend To Know Crypto
#     -RagnaBTC
# RagnaBTC
# MacroCRG
#     -MacroCRG
# 🔥🔥🔥🐺GERI & FREKI🐺🔥🔥🔥
#     -Grayscale
# Grayscale
# Jaime Baker
#     -Grayscale
# Tom molrn
#     -Coinme
# Coinme
# Lindsay Crews
#     -CoinDesk
# CoinDesk
# Juan Llanos
#     -CoinDesk
# Renko
#     -CoinDesk
# BtCDrAfTeR
#     -CoinDesk
# Satoshi Reaper
#     -WhalePanda
# WhalePanda
# latetot.eth
#     -WhalePanda
# /home/matthew/Programming/tmresearch/venv/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 128293 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# Out:
#                           created_at  favorite_count            id  \
# 1745  Wed Jul 10 15:34:25 +0000 2019               0  1.148979e+18
# 4201  Wed Jul 10 16:34:01 +0000 2019               0  1.148994e+18
# 4455  Wed Jul 10 16:40:14 +0000 2019               0  1.148995e+18
#
#      in_reply_to_screen_name  in_reply_to_user_id  retweet_count  retweet_id  \
# 1745            TraderSeneca         1.095671e+18              0         NaN
# 4201            TraderSeneca         1.095671e+18              0         NaN
# 4455         TomasPhilosophy         7.162592e+17              0         NaN
#
#       retweet_screen_name                                               text  \
# 1745                  NaN  @TraderSeneca Nothing of Bitcoins history indi...
# 4201                  NaN  @TraderSeneca I understand. But then again, Bi...
# 4455                  NaN  @TraderSeneca To look at history to learn is a...
#
#                                               tweet_url user_name  \
# ...
